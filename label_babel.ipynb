# %%
import pandas as pd
import spacy

# %%
VALID_CSV = 'data/label_babel/label_babel_valid_2020-01-02.csv'
TRAIN_CSV = 'data/label_babel/label_babel_train_2020-01-02.csv'

INPUT_CSV = VALID_CSV
INPUT_COL = 'predicted_text'

# %%
spacy.prefer_gpu()
nlp = spacy.load('en_core_web_md')

df = pd.read_csv(INPUT_CSV, na_filter=False, dtype=str)

# %%
for doc in nlp.pipe(df[INPUT_COL]):
#     for ent in doc.ents:
#         print(f'{ent.start_char}\t{ent.end_char}\t{ent.label_:8s}  {ent.text.strip()}')
    for token in doc:
        print(f'{token.pos_}\t{token.is_oov}\t{token.text.strip()}')
    break
# Out:
# NOUN	False	FLORA
# ADP	False	OF
# PROPN	False	ARK
# PUNCT	False	:
# SPACE	False
# PROPN	True	CORNACEAE
# PROPN	False	Cornus
# PROPN	True	drummondii
# PROPN	False	C
# PROPN	False	A.
# PROPN	False	Mey
# PUNCT	False	.
# PUNCT	False	,
# SPACE	False
# ADJ	False	rough
# PUNCT	False	-
# NOUN	False	leaved
# NOUN	False	dogwood
# PUNCT	False	.
# SPACE	False
# PROPN	False	YELL
# PROPN	False	COUNTY
# PUNCT	False	:
# PROPN	False	Casa
# PROPN	False	AR
# NUM	False	7.5
# PUNCT	False	'
# NOUN	False	Topo
# PUNCT	False	.
# INTJ	False	Quad
# PUNCT	False	.
# SPACE	False
# ADP	False	Along
# PROPN	False	Mill
# PROPN	False	Creek
# PUNCT	False	,
# ADV	False	just
# ADV	False	north
# ADP	False	of
# DET	False	the
# NOUN	False	intersection
# ADP	False	of
# SPACE	False
# PROPN	True	Hwys
# PUNCT	False	.
# NUM	False	154
# CCONJ	False	and
# NUM	False	155
# PUNCT	False	,
# ADV	False	just
# ADV	False	west
# ADP	False	of
# PROPN	False	New
# PROPN	False	Neely
# PUNCT	False	,
# NOUN	False	approx
# PUNCT	False	.
# SPACE	False
# NUM	False	7.5
# NOUN	False	miles
# ADV	False	south
# ADP	False	of
# PROPN	False	AR
# PROPN	False	Hwy
# PUNCT	False	.
# NUM	False	7
# PUNCT	False	;
# VERB	False	located
# ADP	False	in
# NOUN	False	creekside
# SPACE	False
# NOUN	False	thicket
# PUNCT	False	;
# ADV	False	just
# ADP	False	about
# DET	False	the
# PROPN	False	SE
# NOUN	False	corner
# ADP	False	of
# DET	False	the
# PROPN	False	NE
# NUM	False	1/4
# ADP	False	of
# PROPN	False	NW
# SPACE	False
# PROPN	True	V/4
# CCONJ	False	and
# PROPN	False	SW
# NOUN	False	corner
# ADP	False	of
# PROPN	False	NW
# NUM	False	1/4
# ADP	False	of
# DET	False	the
# PROPN	False	NE
# NUM	False	1/4
# ADP	False	of
# NOUN	False	Sect
# NUM	False	2
# PUNCT	False	.
# SPACE	False
# PROPN	False	TSN
# PUNCT	False	,
# PROPN	True	R20W
# PUNCT	False	;
# PROPN	False	Lat
# PROPN	False	.
# NUM	True	35.11590
# PROPN	False	°
# PROPN	False	N
# PUNCT	False	,
# PROPN	False	Long
# PUNCT	False	.
# PUNCT	True	-93.09481
# PUNCT	False	'
# NOUN	False	W
# PUNCT	False	:
# NUM	False	91
# SPACE	False
# NUM	False	m
# ADP	False	above
# NOUN	False	sea
# NOUN	False	level
# PUNCT	False	;
# ADJ	False	large
# NOUN	False	shrub
# SYM	False	/
# ADJ	False	small
# NOUN	False	tree
# PUNCT	False	,
# ADJ	False	common
# ADP	False	in
# SPACE	False
# NOUN	False	area
# ADP	False	along
# NOUN	False	edges
# ADP	False	of
# NOUN	False	e
# PUNCT	False	,
# PROPN	False	Woods
# VERB	False	edges
# PUNCT	False	,
# CCONJ	False	and
# NOUN	False	edges
# ADP	False	of
# SPACE	False
# NOUN	False	thickets
# PUNCT	False	;
# NOUN	False	flowers
# ADJ	False	bright
# ADJ	False	white
# PUNCT	False	,
# VERB	False	leaves
# ADV	False	somewhat
# ADJ	False	velvety
# SPACE	False
# ADP	False	to
# DET	False	the
# NOUN	False	touch
# PUNCT	False	,
# SPACE	False
# PROPN	False	George
# PROPN	False	P.
# PROPN	False	Johnson
# PUNCT	False	—
# SYM	False	#
# NUM	True	5794
# NUM	False	12
# PROPN	False	May
# NUM	False	2009
