# %%
import numpy as np
import pandas as pd

# %%
in_file = 'vntraits110715'
out_file = in_file + '.csv'

# %%
df = pd.read_csv(in_file)
df.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (3,6,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     occurrenceid institutionid collectionid datasetid  \
# 0  urn:catalog:USAC:Mamíferos:20           NaN          NaN       NaN
# 1  urn:catalog:USAC:Mamíferos:22           NaN          NaN       NaN
# 2  urn:catalog:USAC:Mamíferos:60           NaN          NaN       NaN
# 3  urn:catalog:USAC:Mamíferos:61           NaN          NaN       NaN
# 4  urn:catalog:USAC:Mamíferos:63           NaN          NaN       NaN
#
#   institutioncode collectioncode catalognumber    scientificname     class  \
# 0            USAC      Mamíferos            20  Marmosa mexicana  Mammalia
# 1            USAC      Mamíferos            22  Marmosa mexicana  Mammalia
# 2            USAC      Mamíferos            60  Sorex veraepacis  Mammalia
# 3            USAC      Mamíferos            61  Sorex veraepacis  Mammalia
# 4            USAC      Mamíferos            63  Sorex veraepacis  Mammalia
#
#    individualcount     sex lifestage  \
# 0              NaN  female   unknown
# 1              NaN    male   unknown
# 2              NaN  female   unknown
# 3              NaN  female   unknown
# 4              NaN  female   unknown
#
#                                    dynamicproperties  \
# 0  {"totalLengthInMM":"270-165-18-22-31", "tailLe...
# 1  {"totalLengthInMM":"310", "tailLengthInMM":"18...
# 2  {"totalLengthInMM":"142", "tailLengthInMM":"60...
# 3  {"totalLengthInMM":"137", "tailLengthInMM":"54...
# 4  {"totalLengthInMM":"145", "tailLengthInMM":"63...
#
#                                    occurrenceremarks fieldnotes
# 0  Etiqueta de piel y de material óseo con número...        NaN
# 1        este es el número de catálogo SLOU 73, JOCC        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                                NaN        NaN

# %%
df['dwc_sex'] = None
df['dwc_sex_source'] = None
df['dwc_lifeStage'] = None
df['dwc_lifeStage_source'] = None
df['vto_bodyLength'] = None
df['vto_bodyLength_units'] = None
df['vto_bodyLength_source'] = None
df['vto_bodyMass'] = None
df['vto_bodyMass_units'] = None
df['vto_bodyMass_source'] = None
df.head()
# Out:
#                     occurrenceid institutionid collectionid datasetid  \
# 0  urn:catalog:USAC:Mamíferos:20           NaN          NaN       NaN
# 1  urn:catalog:USAC:Mamíferos:22           NaN          NaN       NaN
# 2  urn:catalog:USAC:Mamíferos:60           NaN          NaN       NaN
# 3  urn:catalog:USAC:Mamíferos:61           NaN          NaN       NaN
# 4  urn:catalog:USAC:Mamíferos:63           NaN          NaN       NaN
#
#   institutioncode collectioncode catalognumber    scientificname     class  \
# 0            USAC      Mamíferos            20  Marmosa mexicana  Mammalia
# 1            USAC      Mamíferos            22  Marmosa mexicana  Mammalia
# 2            USAC      Mamíferos            60  Sorex veraepacis  Mammalia
# 3            USAC      Mamíferos            61  Sorex veraepacis  Mammalia
# 4            USAC      Mamíferos            63  Sorex veraepacis  Mammalia
#
#    individualcount         ...         dwc_sex dwc_sex_source dwc_lifeStage  \
# 0              NaN         ...             NaN            NaN           NaN
# 1              NaN         ...             NaN            NaN           NaN
# 2              NaN         ...             NaN            NaN           NaN
# 3              NaN         ...             NaN            NaN           NaN
# 4              NaN         ...             NaN            NaN           NaN
#
#   dwc_lifeStage_source vto_bodyLength vto_bodyLength_units  \
# 0                  NaN            NaN                  NaN
# 1                  NaN            NaN                  NaN
# 2                  NaN            NaN                  NaN
# 3                  NaN            NaN                  NaN
# 4                  NaN            NaN                  NaN
#
#   vto_bodyLength_source vto_bodyMass vto_bodyMass_units vto_bodyMass_source
# 0                   NaN          NaN                NaN                 NaN
# 1                   NaN          NaN                NaN                 NaN
# 2                   NaN          NaN                NaN                 NaN
# 3                   NaN          NaN                NaN                 NaN
# 4                   NaN          NaN                NaN                 NaN
#
# [5 rows x 25 columns]

# %%
df = df.replace(np.NaN, '')
df.head()
# Out:
#                     occurrenceid institutionid collectionid datasetid  \
# 0  urn:catalog:USAC:Mamíferos:20
# 1  urn:catalog:USAC:Mamíferos:22
# 2  urn:catalog:USAC:Mamíferos:60
# 3  urn:catalog:USAC:Mamíferos:61
# 4  urn:catalog:USAC:Mamíferos:63
#
#   institutioncode collectioncode catalognumber    scientificname     class  \
# 0            USAC      Mamíferos            20  Marmosa mexicana  Mammalia
# 1            USAC      Mamíferos            22  Marmosa mexicana  Mammalia
# 2            USAC      Mamíferos            60  Sorex veraepacis  Mammalia
# 3            USAC      Mamíferos            61  Sorex veraepacis  Mammalia
# 4            USAC      Mamíferos            63  Sorex veraepacis  Mammalia
#
#   individualcount         ...         dwc_sex dwc_sex_source dwc_lifeStage  \
# 0                         ...
# 1                         ...
# 2                         ...
# 3                         ...
# 4                         ...
#
#   dwc_lifeStage_source vto_bodyLength vto_bodyLength_units  \
# 0
# 1
# 2
# 3
# 4
#
#   vto_bodyLength_source vto_bodyMass vto_bodyMass_units vto_bodyMass_source
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 25 columns]

# %%
df.to_csv(out_file)
